# %% [markdown]
# <a href="https://colab.research.google.com/github/hwillif/AI-Calorie-CCN-Food-Detection-Project/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('This is a test to see if it works')
# Out:
# This is a test to see if it works

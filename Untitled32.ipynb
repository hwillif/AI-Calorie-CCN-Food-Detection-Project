# %% [markdown]
# <a href="https://colab.research.google.com/github/hwillif/AI-Calorie-CCN-Food-Detection-Project/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
